# %% [markdown]
# <a href="https://colab.research.google.com/github/yooon27/Embedded-Software-Contest2023/blob/main/roboflow_practice_yolov5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !curl -L "https://public.roboflow.com/ds/XuEYNzkV8P?key=tavzG5usNE" > roboflow.zip; unzip roboflow.zip; rm roboflow.zip

# %%
# %cd /content
# !git clone https://github.com/ultralytics/yolov5.git

# %%
# %cd /content/yolov5/
# !pip install -r requirements.txt
#필요 패키지 설치

# %%
# %cat /content/dataset/data.yaml
#nc는 클래스 갯수
#names는 클래스 이름

# %%
# %cd /
from glob import glob

img_list = glob('/content/dataset/train/images/*.jpg')

print(len(img_list))

#train 의 이미지 갯수 확

# %%
train_img_list = glob('/content/dataset/train/images/*.jpg')
val_img_list = glob('/content/dataset/valid/images/*.jpg')

with open('/content/dataset/train.txt','w') as f:
  f.write('\n'.join(train_img_list)+'\n')
with open('/content/dataset/val.txt','w') as f:
  f.write('\n'.join(val_img_list)+'\n')

# %%
import yaml

with open('/content/dataset/data.yaml','r')as f:
  data = yaml.full_load(f)

print(data)

data['train'] = '/content/dataset/train.txt'
data['val'] = '/content/dataset/val.txt'

with open('/content/dataset/data.yaml', 'w') as f:
  yaml.dump(data, f)

print(data)
# Out:
# {'names': ['fish', 'jellyfish', 'penguin', 'puffin', 'shark', 'starfish', 'stingray'], 'nc': 7, 'train': '/content/dataset/train.txt', 'val': '/content/dataset/val.txt'}
# {'names': ['fish', 'jellyfish', 'penguin', 'puffin', 'shark', 'starfish', 'stingray'], 'nc': 7, 'train': '/content/dataset/train.txt', 'val': '/content/dataset/val.txt'}

# %%
# %cd /content/yolov5/

# !python train.py --img 640 --batch 16 --epochs 60 --data /content/dataset/data.yaml --cfg ./models/yolov5m.yaml --weights yolov5m.pt --name aquarium_yolov5m_result
# Out:
# /content/yolov5
# train: weights=yolov5m.pt, cfg=./models/yolov5m.yaml, data=/content/dataset/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=60, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=aquarium_yolov5m_result, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-193-g485da42 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# 100% 755k/755k [00:00<00:00, 17.3MB/s]
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5m.pt to yolov5m.pt...
# 100% 40.8M/40.8M [00:00<00:00, 98.4MB/s]
#
# Overriding model.yaml nc=80 with nc=7
#
#                  from  n    params  module                                  arguments
#   0                -1  1      5280  models.common.Conv                      [3, 48, 6, 2, 2]
#   1                -1  1     41664  models.common.Conv                      [48, 96, 3, 2]
#   2                -1  2     65280  models.common.C3                        [96, 96, 2]
#   3                -1  1    166272  models.common.Conv                      [96, 192, 3, 2]
#   4                -1  4    444672  models.common.C3                        [192, 192, 4]
#   5                -1  1    664320  models.common.Conv                      [192, 384, 3, 2]
#   6                -1  6   2512896  models.common.C3                        [384, 384, 6]
#   7                -1  1   2655744  models.common.Conv                      [384, 768, 3, 2]
#   8                -1  2   4134912  models.common.C3                        [768, 768, 2]
#   9                -1  1   1476864  models.common.SPPF                      [768, 768, 5]
#  10                -1  1    295680  models.common.Conv                      [768, 384, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  2   1182720  models.common.C3                        [768, 384, 2, False]
#  14                -1  1     74112  models.common.Conv                      [384, 192, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  2    296448  models.common.C3                        [384, 192, 2, False]
#  18                -1  1    332160  models.common.Conv                      [192, 192, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  2   1035264  models.common.C3                        [384, 384, 2, False]
#  21                -1  1   1327872  models.common.Conv                      [384, 384, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  2   4134912  models.common.C3                        [768, 768, 2, False]
#  24      [17, 20, 23]  1     48492  models.yolo.Detect                      [7, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [192, 384, 768]]
# YOLOv5m summary: 291 layers, 20895564 parameters, 20895564 gradients, 48.3 GFLOPs
#
# Transferred 474/481 items from yolov5m.pt
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 79 weight(decay=0.0), 82 weight(decay=0.0005), 82 bias
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# train: Scanning /content/dataset/train... 448 images, 1 backgrounds, 0 corrupt: 100% 448/448 [00:00<00:00, 1659.67it/s]
# train: New cache created: /content/dataset/train.cache
# val: Scanning /content/dataset/val... 127 images, 0 backgrounds, 0 corrupt: 100% 127/127 [00:00<00:00, 763.83it/s]
# val: New cache created: /content/dataset/val.cache
#
# AutoAnchor: 5.17 anchors/target, 0.999 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to runs/train/aquarium_yolov5m_result/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/train/aquarium_yolov5m_result
# Starting training for 60 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        0/59      6.17G     0.1089    0.07626    0.05427        181        640: 100% 28/28 [00:31<00:00,  1.13s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:08<00:00,  2.07s/it]
#                    all        127        909      0.057     0.0777     0.0299    0.00811
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        1/59      7.41G    0.08563    0.07569    0.04368        208        640: 100% 28/28 [00:22<00:00,  1.22it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0% 0/4 [00:00<?, ?it/s]WARNING ⚠️ NMS time limit 2.100s exceeded
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:08<00:00,  2.14s/it]
#                    all        127        909      0.474      0.137     0.0489      0.016
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        2/59      7.41G    0.07829    0.06525    0.04076        180        640: 100% 28/28 [00:24<00:00,  1.17it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:05<00:00,  1.35s/it]
#                    all        127        909      0.702      0.166      0.143     0.0517
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        3/59      7.41G     0.0783     0.0636    0.03664        156        640: 100% 28/28 [00:25<00:00,  1.10it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:04<00:00,  1.02s/it]
#                    all        127        909      0.419      0.249       0.15     0.0431
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        4/59      7.41G    0.06855    0.06533    0.03078        138        640: 100% 28/28 [00:25<00:00,  1.11it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:03<00:00,  1.09it/s]
#                    all        127        909      0.551      0.228      0.184     0.0672
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        5/59      7.41G    0.06252    0.05878    0.02828        203        640: 100% 28/28 [00:24<00:00,  1.14it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:03<00:00,  1.04it/s]
#                    all        127        909      0.698      0.237      0.195     0.0763
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        6/59      7.41G     0.0589    0.06345    0.02469        247        640: 100% 28/28 [00:23<00:00,  1.17it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:05<00:00,  1.40s/it]
#                    all        127        909       0.77      0.231      0.302      0.135
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        7/59      7.41G     0.0556    0.05825    0.02289        204        640: 100% 28/28 [00:25<00:00,  1.12it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:03<00:00,  1.27it/s]
#                    all        127        909       0.23      0.533      0.297      0.122
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        8/59      7.41G    0.05413     0.0606    0.02082        205        640: 100% 28/28 [00:25<00:00,  1.09it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:03<00:00,  1.29it/s]
#                    all        127        909      0.274      0.568      0.394      0.178
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        9/59      7.41G    0.05171    0.05589    0.01939        179        640: 100% 28/28 [00:24<00:00,  1.15it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:02<00:00,  1.35it/s]
#                    all        127        909      0.475      0.571      0.469      0.214
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       10/59      7.41G    0.04868     0.0541    0.01757        148        640: 100% 28/28 [00:22<00:00,  1.22it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:04<00:00,  1.05s/it]
#                    all        127        909      0.466      0.602      0.514      0.245
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       11/59      7.41G    0.04842    0.05658    0.01642        190        640: 100% 28/28 [00:23<00:00,  1.19it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:04<00:00,  1.11s/it]
#                    all        127        909      0.476      0.609       0.52       0.26
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       12/59      7.41G     0.0467    0.05228    0.01565        129        640: 100% 28/28 [00:25<00:00,  1.10it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:02<00:00,  1.34it/s]
#                    all        127        909      0.575      0.601      0.574      0.291
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       13/59      7.41G    0.04644     0.0518    0.01374        138        640: 100% 28/28 [00:25<00:00,  1.11it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:03<00:00,  1.29it/s]
#                    all        127        909      0.635       0.63      0.633      0.334
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       14/59      7.41G    0.04554    0.05487    0.01321        256        640: 100% 28/28 [00:23<00:00,  1.19it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:03<00:00,  1.18it/s]
#                    all        127        909      0.721      0.678      0.718      0.398
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       15/59      7.41G    0.04513    0.05406    0.01107        194        640: 100% 28/28 [00:23<00:00,  1.21it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:02<00:00,  1.38it/s]
#                    all        127        909      0.797      0.667      0.711      0.377
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       16/59      7.41G    0.04276    0.04685    0.01112        125        640: 100% 28/28 [00:23<00:00,  1.17it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:02<00:00,  1.38it/s]
#                    all        127        909      0.816      0.622      0.706      0.391
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       17/59      7.41G    0.04198    0.05065   0.009934        192        640: 100% 28/28 [00:23<00:00,  1.17it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:03<00:00,  1.31it/s]
#                    all        127        909      0.799      0.665      0.731       0.38
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       18/59      7.41G    0.04154    0.05512    0.00904        150        640: 100% 28/28 [00:23<00:00,  1.18it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:03<00:00,  1.17it/s]
#                    all        127        909       0.64      0.638      0.591      0.305
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       19/59      7.41G    0.04174    0.05004   0.008549        192        640: 100% 28/28 [00:23<00:00,  1.19it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:03<00:00,  1.09it/s]
#                    all        127        909      0.753      0.688      0.723      0.403
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       20/59      7.41G    0.04116    0.05135   0.007681        272        640: 100% 28/28 [00:22<00:00,  1.22it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:04<00:00,  1.08s/it]
#                    all        127        909      0.817      0.665      0.746      0.414
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       21/59      7.41G    0.04085    0.04979   0.007571        228        640: 100% 28/28 [00:23<00:00,  1.21it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:04<00:00,  1.19s/it]
#                    all        127        909       0.78      0.714       0.76      0.419
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       22/59      7.41G    0.04033    0.04897   0.007097        231        640: 100% 28/28 [00:24<00:00,  1.16it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:03<00:00,  1.15it/s]
#                    all        127        909      0.817      0.721      0.773      0.424
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       23/59      7.41G    0.03972    0.05047   0.006128        177        640: 100% 28/28 [00:24<00:00,  1.13it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:02<00:00,  1.37it/s]
#                    all        127        909      0.774      0.733       0.76      0.434
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       24/59      7.41G    0.03853    0.04918   0.006202        162        640: 100% 28/28 [00:24<00:00,  1.15it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:02<00:00,  1.37it/s]
#                    all        127        909      0.818      0.721      0.765      0.428
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       25/59      7.41G    0.03813    0.04798   0.006117        173        640: 100% 28/28 [00:23<00:00,  1.18it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:02<00:00,  1.38it/s]
#                    all        127        909      0.759      0.735      0.764      0.444
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       26/59      7.41G     0.0376    0.04655   0.005491        162        640: 100% 28/28 [00:22<00:00,  1.23it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:03<00:00,  1
00:00,  1.11it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:02<00:00,  1.34it/s]
#                    all        127        909      0.825      0.772      0.796      0.493
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       50/59      7.41G    0.02866    0.04062   0.002149        218        640: 100% 28/28 [00:25<00:00,  1.10it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:03<00:00,  1.29it/s]
#                    all        127        909      0.835      0.744      0.802      0.494
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       51/59      7.41G    0.02823    0.03922   0.002361        215        640: 100% 28/28 [00:24<00:00,  1.13it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:03<00:00,  1.32it/s]
#                    all        127        909      0.859      0.737      0.806      0.502
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       52/59      7.41G    0.02863    0.03914   0.002216        155        640: 100% 28/28 [00:24<00:00,  1.13it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:02<00:00,  1.39it/s]
#                    all        127        909       0.82      0.779      0.803      0.493
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       53/59      7.41G    0.02746    0.03821   0.001994        182        640: 100% 28/28 [00:25<00:00,  1.12it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:03<00:00,  1.29it/s]
#                    all        127        909      0.842      0.756      0.803      0.492
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       54/59      7.41G    0.02767    0.03746   0.002192        140        640: 100% 28/28 [00:24<00:00,  1.13it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:02<00:00,  1.37it/s]
#                    all        127        909      0.818      0.758        0.8      0.498
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       55/59      7.41G    0.02798    0.04217   0.002124        220        640: 100% 28/28 [00:24<00:00,  1.12it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:03<00:00,  1.31it/s]
#                    all        127        909      0.808      0.767      0.804      0.502
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       56/59      7.41G    0.02779     0.0385   0.001991        253        640: 100% 28/28 [00:24<00:00,  1.15it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:02<00:00,  1.44it/s]
#                    all        127        909      0.838      0.753      0.806      0.506
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       57/59      7.41G    0.02708    0.03793   0.002011        182        640: 100% 28/28 [00:22<00:00,  1.22it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:04<00:00,  1.23s/it]
#                    all        127        909      0.858      0.733      0.814      0.509
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       58/59      7.41G    0.02679    0.03878   0.001844        194        640: 100% 28/28 [00:22<00:00,  1.22it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:04<00:00,  1.13s/it]
#                    all        127        909       0.82      0.772      0.811      0.503
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       59/59      7.41G    0.02683    0.03629   0.001654        219        640: 100% 28/28 [00:23<00:00,  1.21it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:04<00:00,  1.19s/it]
#                    all        127        909      0.821      0.778      0.809      0.503
#
# 60 epochs completed in 0.525 hours.
# Optimizer stripped from runs/train/aquarium_yolov5m_result/weights/last.pt, 42.2MB
# Optimizer stripped from runs/train/aquarium_yolov5m_result/weights/best.pt, 42.2MB
#
# Validating runs/train/aquarium_yolov5m_result/weights/best.pt...
# Fusing layers...
# YOLOv5m summary: 212 layers, 20877180 parameters, 0 gradients, 47.9 GFLOPs
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:07<00:00,  1.78s/it]
#                    all        127        909      0.857      0.733      0.815      0.509
#                   fish        127        459      0.884      0.756      0.853      0.509
#              jellyfish        127        155      0.908      0.892      0.954      0.566
#                penguin        127        104      0.747      0.731      0.754      0.377
#                 puffin        127         74      0.828      0.586      0.676      0.356
#                  shark        127         57       0.95      0.665       0.81      0.529
#               starfish        127         27      0.894      0.741      0.812      0.597
#               stingray        127         33      0.788      0.758      0.843      0.631
# Results saved to runs/train/aquarium_yolov5m_result

# %%
# %load_ext tensorboard
# %tensorboard --logdir /content/yolov5/runs

# %%
from IPython.display import Image
import os

val_img_path = val_img_list[3]

# !python detect.py --weights /content/yolov5/runs/train/aquarium_yolov5m_result/weights/best.pt --img 640 --conf 0.5 --source "{val_img_path}"

Image(os.path.join('/content/yolov5/runs/detect/exp6', os.path.basename(val_img_path)))
# Out:
# detect: weights=['/content/yolov5/runs/train/aquarium_yolov5m_result/weights/best.pt'], source=/content/dataset/valid/images/IMG_2523_jpeg_jpg.rf.efd9f79430fc015890b4a4ad5ddfe3ad.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-193-g485da42 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5m summary: 212 layers, 20877180 parameters, 0 gradients, 47.9 GFLOPs
# image 1/1 /content/dataset/valid/images/IMG_2523_jpeg_jpg.rf.efd9f79430fc015890b4a4ad5ddfe3ad.jpg: 640x480 4 fishs, 11 puffins, 46.3ms
# Speed: 0.5ms pre-process, 46.3ms inference, 2.0ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp6
